# %% [markdown]
# # Universal differential equation for SIR ODE model

# %% [markdown]
# The script provided below is closely based on and inspired by the tutorial available at the following link: https://docs.sciml.ai/Overview/stable/showcase/missing_physics/

# %%
# SciML Tools
using OrdinaryDiffEq, SciMLSensitivity, Optimization, OptimizationOptimisers, OptimizationOptimJL

# Standard Libraries
using LinearAlgebra, Statistics, Random, Distributions

# External Libraries
using ComponentArrays, Lux, Zygote, Plots, StableRNGs
gr()

# Set a random seed for reproducible behaviour
rng = StableRNG(1111);

# %% [markdown]
# ### Define the SIR dynamics and solve the ODE

# %%
function sir!(du, u, p, t)
    β, γ, N = p
    du[1] = -β*u[1]*u[2]/N
    du[2] = β*u[1]*u[2]/N - γ*u[2]
    du[3] = γ*u[2]
end

p_ODE = [0.6, 0.3, 1.0]
u0 = [0.999, 0.001, 0.0]
tspan = (0.0, 40.0);

# %%
prob = ODEProblem(sir!, u0, tspan, p_ODE)
sol = solve(prob, Tsit5(), abstol = 1e-12, reltol = 1e-12, saveat = 1.0);

# %%
plot(sol, xlabel = "Time", ylabel = "Number of individuals", labels = ["S" "I" "R"])

# %% [markdown]
# ### Add multiplicative log-normal noise

# %%
t = sol.t
X = Array(sol)
dist = LogNormal(0, 0.01)
noise = rand(rng, dist, size(X))
X_noisy = noise .* X;

# %%
plot(t, X', xlabel = "Time", ylabel = "Number of individuals",
     color = :black, label=["True trajectory" nothing nothing])
scatter!(t, X_noisy', color = :red, label=["Noisy data" nothing nothing])

# %% [markdown]
# ### Set up the UDE

# %% [markdown]
# We set up our UDE by first defining the NN component and then the hybrid model $u'=f(u)+\text{NN}(u)$.

# %%
# Define activation function
rbf(x) = exp.(-(x .^ 2))   

# Multi-layer feed-forward neural network
model = Chain(Dense(3, 5, rbf), Dense(5, 5, rbf), Dense(5, 2))

# Get initial parameters and state variables of the model
p_init, st = Lux.setup(rng, model);

# %%
# Define the hybrid model
β, γ, N = p_ODE

function ude_dynamics!(du, u, p, t)
    nn = Lux.apply(model, u, p, st)[1]   # Network prediction    
    du[1] = nn[1]
    du[2] = -γ*u[2] + nn[2] 
    du[3] = γ*u[2]
end

prob_ude = ODEProblem(ude_dynamics!, u0, tspan, p_init);

# %% [markdown]
# ### Set up the training

# %%
function predict(p)   # p is the parameter of the NN and the ODE at the same time
    _prob = remake(prob_ude, p=p)
    Array(solve(_prob, Tsit5(), abstol = 1e-6, reltol = 1e-6, saveat = t,
                sensealg=QuadratureAdjoint(autojacvec=ReverseDiffVJP(true))))
end;

# %%
function loss(p)
    X̂ = predict(p)
    mean(abs2, X_noisy .- X̂)   # MSE loss
end;

# %%
losses = Float64[]

function callback(p, l)
    push!(losses, l)
    n_iter = length(losses)
    if n_iter % 50 == 0   
        println("Loss after $(n_iter) iterations: $(losses[end])")
    end
    return false
end;

# %% [markdown]
# ### Train the UDE

# %%
adtype = AutoZygote()   # automatic differentiation
optf = OptimizationFunction((p, _) -> loss(p), adtype)
optprob = OptimizationProblem(optf, ComponentVector{Float64}(p_init));

# %%
res1 = solve(optprob, ADAM(), callback = callback, maxiters = 5000);
# Out:
# Loss after 50 iterations: 111.15470275904595
# Loss after 100 iterations: 7.7767227318415975
# Loss after 150 iterations: 2.22733344263582
# Loss after 200 iterations: 0.6800184344587122
# Loss after 250 iterations: 0.17210514624140866
# Loss after 300 iterations: 0.04001821033903105
# Loss after 350 iterations: 0.03162401026632271
# Loss after 400 iterations: 0.03081132057159312
# Loss after 450 iterations: 0.029918059106961586
# Loss after 500 iterations: 0.02892904455649426
# Loss after 550 iterations: 0.027835966032202758
# Loss after 600 iterations: 0.02662957810962801
# Loss after 650 iterations: 0.025300670597381145
# Loss after 700 iterations: 0.023841849628369455
# Loss after 750 iterations: 0.022250548340223945
# Loss after 800 iterations: 0.020533601997577852
# Loss after 850 iterations: 0.018713178998546603
# Loss after 900 iterations: 0.0168324669558736
# Loss after 950 iterations: 0.014957330895865428
# Loss after 1000 iterations: 0.013168887433979419
# Loss after 1050 iterations: 0.011545078118274042
# Loss after 1100 iterations: 0.010138013673430738
# Loss after 1150 iterations: 0.008960646951131208
# Loss after 1200 iterations: 0.007991101275432183
# Loss after 1250 iterations: 0.007189411279406692
# Loss after 1300 iterations: 0.006514491578168672
# Loss after 1350 iterations: 0.005933702590543729
# Loss after 1400 iterations: 0.005424927025262353
# Loss after 1450 iterations: 0.0049745662081100836
# Loss after 1500 iterations: 0.004574511335339225
# Loss after 1550 iterations: 0.0042196230109708055
# Loss after 1600 iterations: 0.0039061019089614095
# Loss after 1650 iterations: 0.0036306080517669683
# Loss after 1700 iterations: 0.0033898635461416604
# Loss after 1750 iterations: 0.0031805225075976352
# Loss after 1800 iterations: 0.0029991715979843917
# Loss after 1850 iterations: 0.0028423872510741073
# Loss after 1900 iterations: 0.002706812642839219
# Loss after 1950 iterations: 0.002589234590410914
# Loss after 2000 iterations: 0.0024866508403657583
# Loss after 2050 iterations: 0.0023963222886150175
# Loss after 2100 iterations: 0.0023158075906278275
# Loss after 2150 iterations: 0.002242980524307854
# Loss after 2200 iterations: 0.0021760316947981775
# Loss after 2250 iterations: 0.002113457194702486
# Loss after 2300 iterations: 0.0020540373368022357
# Loss after 2350 iterations: 0.0019968086692399435
# Loss after 2400 iterations: 0.0019410323210950647
# Loss after 2450 iterations: 0.0018861610594157626
# Loss after 2500 iterations: 0.0018318070451295567
# Loss after 2550 iterations: 0.0017777117173648968
# Loss after 2600 iterations: 0.0017237187363201235
# Loss after 2650 iterations: 0.0016697504892441318
# Loss after 2700 iterations: 0.0016157883201585771
# Loss after 2750 iterations: 0.001561856376609281
# Loss after 2800 iterations: 0.001508008789448305
# Loss after 2850 iterations: 0.001454319796923236
# Loss after 2900 iterations: 0.0014008763617876794
# Loss after 2950 iterations: 0.0013477728309700405
# Loss after 3000 iterations: 0.0012951071875439146
# Loss after 3050 iterations: 0.001242978529557025
# Loss after 3100 iterations: 0.0011914854258444692
# Loss after 3150 iterations: 0.0011407248862023284
# Loss after 3200 iterations: 0.0010907917042394684
# Loss after 3250 iterations: 0.0010417780562546406
# Loss after 3300 iterations: 0.0009937731874834774
# Loss after 3350 iterations: 0.0009468631221582062
# Loss after 3400 iterations: 0.0009011303538164919
# Loss after 3450 iterations: 0.0008566534647067353
# Loss after 3500 iterations: 0.0008135066533198572
# Loss after 3550 iterations: 0.0007717591921349685
# Loss after 3600 iterations: 0.0007314748205532699
# Loss after 3650 iterations: 0.000692711085185408
# Loss after 3700 iterations: 0.0006555186543720312
# Loss after 3750 iterations: 0.0006199406418893576
# Loss after 3800 iterations: 0.0005860119842300266
# Loss after 3850 iterations: 0.0005537588855856346
# Loss after 3900 iterations: 0.0005231983742171847
# Loss after 3950 iterations: 0.0004943379967885184
# Loss after 4000 iterations: 0.0004671756646432762
# Loss after 4050 iterations: 0.0004416996513155112
# Loss after 4100 iterations: 0.00041788879503792617
# Loss after 4150 iterations: 0.00039571285741399635
# Loss after 4200 iterations: 0.00037513302952801853
# Loss after 4250 iterations: 0.0003561026043671519
# Loss after 4300 iterations: 0.00033856774820565624
# Loss after 4350 iterations: 0.0003224683870161861
# Loss after 4400 iterations: 0.0003077391602944085
# Loss after 4450 iterations: 0.00029431041599690765
# Loss after 4500 iterations: 0.00028210921990301865
# Loss after 4550 iterations: 0.00027106036038538906
# Loss after 4600 iterations: 0.00026108731414328714
# Loss after 4650 iterations: 0.0002521131627967253
# Loss after 4700 iterations: 0.00024406144016375045
# Loss after 4750 iterations: 0.00023685689851426998
# Loss after 4800 iterations: 0.00023042619050004932
# Loss after 4850 iterations: 0.00022469845181536128
# Loss after 4900 iterations: 0.00021960579294242613
# Loss after 4950 iterations: 0.00021508367909099343
# Loss after 5000 iterations: 0.00021107123979987374

# %%
optprob2 = OptimizationProblem(optf, res1.u)
res2 = solve(optprob2, LBFGS(), callback = callback, maxiters = 1000)
p_trained = res2.u;
# Out:
# Loss after 5050 iterations: 0.0001230596841181007
# Loss after 5100 iterations: 3.359203350416287e-5
# Loss after 5150 iterations: 2.5242229925884047e-5
# Loss after 5200 iterations: 2.3928587494980533e-5
# Loss after 5250 iterations: 2.357568425897118e-5
# Loss after 5300 iterations: 2.354072513047397e-5
# Loss after 5350 iterations: 2.3487036289178765e-5
# Loss after 5400 iterations: 2.3467702850271186e-5
# Loss after 5450 iterations: 2.271003916844549e-5
# Loss after 5500 iterations: 2.2310180824422152e-5
# Loss after 5550 iterations: 2.1985608685951428e-5
# Loss after 5600 iterations: 2.172651691474095e-5
# Loss after 5650 iterations: 2.148716129001047e-5
# Loss after 5700 iterations: 2.145395645446165e-5
# Loss after 5750 iterations: 2.1431111751716095e-5
# Loss after 5800 iterations: 2.1428760588648086e-5
# Loss after 5850 iterations: 2.1426860296401426e-5
# Loss after 5900 iterations: 2.1424356631982396e-5
# Loss after 5950 iterations: 2.141425114662578e-5
# Loss after 6000 iterations: 2.140608516290768e-5

# %% [markdown]
# ### Visualize the results

# %%
plot(1:5000, losses[1:5000], yaxis=:log10, xlabel="Iterations", ylabel="Loss", label="ADAM", color=:blue)
plot!(5001:length(losses), losses[5001:end], yaxis=:log10, label="BFGS", color = :red)

# %%
X̂ = predict(p_trained)
plot(t, X̂', xlabel = "Time", ylabel = "Number of individuals", color = :black,
     label = ["UDE approximation" nothing nothing])
scatter!(t, X_noisy', color = :red, label=["Noisy data" nothing nothing])

# %%
plot(t, X̂', xlabel = "Time", ylabel = "Number of individuals", color = :black,
     label = ["UDE approximation" nothing nothing])
plot!(t, X', color = :red, linestyle=:dash, label=["True trajectory" nothing nothing])

# %%
# True residual dynamics (i.e. interactions of predictors) along the true trajectory
dynamics_true = [-β/N * (X[1, :] .* X[2, :])'; β/N * (X[1, :] .* X[2, :])']
# Neural network guess along the approximated trajectory
dynamics_nn = Lux.apply(model, X̂, p_trained, st)[1]

plot(t, dynamics_nn', xlabel = "Time", ylabel = "Residual dynamics", color = :black,
     label = ["NN(S,I,R)" nothing ])
plot!(t, dynamics_true', color = :red, linestyle=:dash, label = ["True" nothing])
