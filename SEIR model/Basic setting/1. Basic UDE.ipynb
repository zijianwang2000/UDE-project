# %% [markdown]
# # Universal differential equation for the SEIR model

# %%
# SciML Tools
using OrdinaryDiffEq, SciMLSensitivity, Optimization, OptimizationOptimisers, OptimizationOptimJL

# Standard Libraries
using LinearAlgebra, Statistics, Random, Distributions

# External Libraries
using ComponentArrays, Lux, Zygote, Plots, StableRNGs
gr()

# Set a random seed for reproducible behaviour
rng = StableRNG(10);

# %% [markdown]
# ### Define the SEIR dynamics and solve the ODE

# %%
function seir!(du, u, p, t)
    α, β, γ, N = p
    du[1] = -β*u[1]*u[3]/N
    du[2] = β*u[1]*u[3]/N - α*u[2]
    du[3] = α*u[2] - γ*u[3]
    du[4] = γ*u[3]
end

p_ODE = [0.3, 1.0, 0.4, 1.0]
u0 = [0.995, 0.004, 0.001, 0.0]
tspan = (0.0, 50.0);

# %%
prob = ODEProblem(seir!, u0, tspan, p_ODE)
sol = solve(prob, Tsit5(), abstol = 1e-12, reltol = 1e-12, saveat = 1.0);

# %%
plot(sol, xlabel = "Time", ylabel = "Number of individuals", labels = ["S" "E" "I" "R"], 
     color = [:blue :goldenrod2 :magenta :green])

# %% [markdown]
# ### Add multiplicative log-normal noise

# %%
t = sol.t
X = Array(sol)
dist = LogNormal(0, 0.05)
noise = rand(rng, dist, size(X[:, begin:5:end]))
X_noisy = noise .* X[:, begin:5:end];

# %%
plot(t, X', xlabel = "Time", ylabel = "Number of individuals", color = [:blue :goldenrod2 :magenta :green], 
     label = ["True trajectory" nothing nothing nothing])
scatter!(t[begin:5:end], X_noisy', color = [:blue :goldenrod2 :magenta :green], 
     label = ["Noisy data" nothing nothing nothing])

# %% [markdown]
# ### Set up the UDE

# %% [markdown]
# We set up our UDE by first defining the NN component and then the hybrid model $u'=f(u)+\text{NN}(u)$.

# %%
# Define activation function
rbf(x) = exp.(-(x .^ 2))   

# Multi-layer feed-forward neural network
model = Chain(Dense(4, 8, rbf), Dense(8, 8, rbf), Dense(8, 8, rbf), Dense(8, 4))

# Get initial parameters and state variables of the model
p_init, st = Lux.setup(rng, model);

# %%
# Define the hybrid model
α, β, γ, N = p_ODE

function ude_dynamics!(du, u, p, t)
    nn = Lux.apply(model, u, p, st)[1]   # Network prediction    
    du[1] = nn[1]
    du[2] = nn[2] 
    du[3] = -γ*u[3] + nn[3]
    du[4] = γ*u[3] + nn[4]
end

prob_ude = ODEProblem(ude_dynamics!, u0, tspan, p_init);

# %% [markdown]
# ### Set up the training

# %%
function predict(p, saveat = t[begin:5:end])   # p is the parameter of the NN and the ODE at the same time
    _prob = remake(prob_ude, p = p)
    Array(solve(_prob, Tsit5(), abstol = 1e-6, reltol = 1e-6, saveat = saveat,
                sensealg = QuadratureAdjoint(autojacvec=ReverseDiffVJP(true))))
end;

# %%
function loss(p)
    X̂ = predict(p)
    mean(abs2, X_noisy .- X̂)   # MSE loss
end;

# %%
losses = Float64[]

function callback(p, l)
    push!(losses, l)
    n_iter = length(losses)
    if n_iter % 50 == 0   
        println("Loss after $(n_iter) iterations: $(losses[end])")
    end
    return false
end;

# %% [markdown]
# ### Train the UDE

# %%
adtype = AutoZygote()   # automatic differentiation
optf = OptimizationFunction((p, _) -> loss(p), adtype)
optprob = OptimizationProblem(optf, ComponentVector{Float64}(p_init));

# %%
res1 = solve(optprob, ADAM(), callback = callback, maxiters = 5000);
# Out:
# Loss after 50 iterations: 51.252097598562955
# Loss after 100 iterations: 3.8295740845981396
# Loss after 150 iterations: 2.044814472047759
# Loss after 200 iterations: 1.06520859658241
# Loss after 250 iterations: 0.7975340752741643
# Loss after 300 iterations: 0.4965636937325541
# Loss after 350 iterations: 0.30731559324896146
# Loss after 400 iterations: 0.21789568944211046
# Loss after 450 iterations: 0.168676266156095
# Loss after 500 iterations: 0.1361162060156591
# Loss after 550 iterations: 0.11212302165148987
# Loss after 600 iterations: 0.09357521123724762
# Loss after 650 iterations: 0.07895951865397344
# Loss after 700 iterations: 0.06739716265336083
# Loss after 750 iterations: 0.058246052625826335
# Loss after 800 iterations: 0.05096931694391385
# Loss after 850 iterations: 0.0451242829118287
# Loss after 900 iterations: 0.04036415151839275
# Loss after 950 iterations: 0.03642700626636271
# Loss after 1000 iterations: 0.03311859467126402
# Loss after 1050 iterations: 0.030295728649751965
# Loss after 1100 iterations: 0.02785269487051605
# Loss after 1150 iterations: 0.02571066974702965
# Loss after 1200 iterations: 0.02381019862694944
# Loss after 1250 iterations: 0.02210576574464914
# Loss after 1300 iterations: 0.02056195708272401
# Loss after 1350 iterations: 0.019150757306021175
# Loss after 1400 iterations: 0.017849636269527295
# Loss after 1450 iterations: 0.016640245723871187
# Loss after 1500 iterations: 0.015507534363761124
# Loss after 1550 iterations: 0.014439150606755791
# Loss after 1600 iterations: 0.013425111281769347
# Loss after 1650 iterations: 0.012457668216302963
# Loss after 1700 iterations: 0.011531444308537482
# Loss after 1750 iterations: 0.010643196025883263
# Loss after 1800 iterations: 0.009792081898226128
# Loss after 1850 iterations: 0.008979315017255808
# Loss after 1900 iterations: 0.008207749665515414
# Loss after 1950 iterations: 0.007481060278239999
# Loss after 2000 iterations: 0.006802759479632339
# Loss after 2050 iterations: 0.006175335495138287
# Loss after 2100 iterations: 0.005599644689189647
# Loss after 2150 iterations: 0.005074906731753182
# Loss after 2200 iterations: 0.004599029537330193
# Loss after 2250 iterations: 0.004169112863799346
# Loss after 2300 iterations: 0.0037819159161004046
# Loss after 2350 iterations: 0.0034342024871687996
# Loss after 2400 iterations: 0.003122786371231855
# Loss after 2450 iterations: 0.0028447100062420193
# Loss after 2500 iterations: 0.0025971559284865327
# Loss after 2550 iterations: 0.0023774593500113157
# Loss after 2600 iterations: 0.002183096536151928
# Loss after 2650 iterations: 0.0020116662705291486
# Loss after 2700 iterations: 0.0018608983088813297
# Loss after 2750 iterations: 0.0017286551396384444
# Loss after 2800 iterations: 0.0016129308789793106
# Loss after 2850 iterations: 0.0015118595156790788
# Loss after 2900 iterations: 0.0014237193480672124
# Loss after 2950 iterations: 0.0013469408334069852
# Loss after 3000 iterations: 0.0012800940279774136
# Loss after 3050 iterations: 0.0012218867673267986
# Loss after 3100 iterations: 0.0011711747048501577
# Loss after 3150 iterations: 0.0011269383082900622
# Loss after 3200 iterations: 0.0010882721025407451
# Loss after 3250 iterations: 0.001054393148128993
# Loss after 3300 iterations: 0.001024606930964187
# Loss after 3350 iterations: 0.0009983230095696632
# Loss after 3400 iterations: 0.0009750189934181517
# Loss after 3450 iterations: 0.0009542662773885352
# Loss after 3500 iterations: 0.0009380595053619156
# Loss after 3550 iterations: 0.0009218310069570186
# Loss after 3600 iterations: 0.0009070439384937684
# Loss after 3650 iterations: 0.000893401517212674
# Loss after 3700 iterations: 0.0008895449774430839
# Loss after 3750 iterations: 0.0008703332799371553
# Loss after 3800 iterations: 0.0008860798066417197
# Loss after 3850 iterations: 0.0008514644696840101
# Loss after 3900 iterations: 0.0008658876693795563
# Loss after 3950 iterations: 0.0008502565881671526
# Loss after 4000 iterations: 0.0008258640073694398
# Loss after 4050 iterations: 0.0008179480219715354
# Loss after 4100 iterations: 0.0008083307520085733
# Loss after 4150 iterations: 0.0008011248777890778
# Loss after 4200 iterations: 0.0007945774622540243
# Loss after 4250 iterations: 0.000792545146455964
# Loss after 4300 iterations: 0.0007978535384474573
# Loss after 4350 iterations: 0.0008149653668126425
# Loss after 4400 iterations: 0.0008456057286269671
# Loss after 4450 iterations: 0.00084043483511548
# Loss after 4500 iterations: 0.0007732663728705933
# Loss after 4550 iterations: 0.0007504768859208415
# Loss after 4600 iterations: 0.0007792027796989482
# Loss after 4650 iterations: 0.0008605137061193952
# Loss after 4700 iterations: 0.0008024386365477427
# Loss after 4750 iterations: 0.0007270419223523685
# Loss after 4800 iterations: 0.0007615359541000047
# Loss after 4850 iterations: 0.000830888652942099
# Loss after 4900 iterations: 0.0007263755664217196
# Loss after 4950 iterations: 0.0007296403652271833
# Loss after 5000 iterations: 0.0008529513634583029

# %%
optprob2 = OptimizationProblem(optf, res1.u)
res2 = solve(optprob2, LBFGS(), callback = callback, maxiters = 5000)
p_trained = res2.u;
# Out:
# Loss after 5050 iterations: 0.0005522795466767744
# Loss after 5100 iterations: 0.00043997389504786885
# Loss after 5150 iterations: 0.00040320730817376417
# Loss after 5200 iterations: 0.00037700747682938214
# Loss after 5250 iterations: 0.00036669802585385654
# Loss after 5300 iterations: 0.00036169238688987245
# Loss after 5350 iterations: 0.00035498996577706287
# Loss after 5400 iterations: 0.0003526274737144017
# Loss after 5450 iterations: 0.0003451992499778546
# Loss after 5500 iterations: 0.0003370101570545883
# Loss after 5550 iterations: 0.0003350547950022433
# Loss after 5600 iterations: 0.00033321455465356583
# Loss after 5650 iterations: 0.0003319397845473948
# Loss after 5700 iterations: 0.000329152026326333
# Loss after 5750 iterations: 0.00032719089836617755
# Loss after 5800 iterations: 0.0003217367723709064
# Loss after 5850 iterations: 0.0003180533543361321
# Loss after 5900 iterations: 0.00031509379055981966
# Loss after 5950 iterations: 0.00031441141762141484
# Loss after 6000 iterations: 0.00031042757356920613
# Loss after 6050 iterations: 0.00030814522314412553
# Loss after 6100 iterations: 0.00030637538420021467
# Loss after 6150 iterations: 0.00030385220424294793
# Loss after 6200 iterations: 0.0003030374548833084
# Loss after 6250 iterations: 0.0003020646457856547
# Loss after 6300 iterations: 0.0003010418990690939
# Loss after 6350 iterations: 0.0002986493909362419
# Loss after 6400 iterations: 0.00029772200079226235
# Loss after 6450 iterations: 0.0002940782286255445
# Loss after 6500 iterations: 0.00028851819846886854
# Loss after 6550 iterations: 0.0002802406609875481
# Loss after 6600 iterations: 0.0002731292146739965
# Loss after 6650 iterations: 0.0002564128999353033
# Loss after 6700 iterations: 0.00024548098591302723
# Loss after 6750 iterations: 0.0002355487799209267
# Loss after 6800 iterations: 0.0002280206422442875
# Loss after 6850 iterations: 0.00022521341888831223
# Loss after 6900 iterations: 0.0002230350936687135
# Loss after 6950 iterations: 0.00021581833028306712
# Loss after 7000 iterations: 0.00020520396126837557
# Loss after 7050 iterations: 0.00019874403753510636
# Loss after 7100 iterations: 0.00019494162833595145
# Loss after 7150 iterations: 0.00019352065909446805
# Loss after 7200 iterations: 0.00018891673131794554
# Loss after 7250 iterations: 0.00018336884191632845
# Loss after 7300 iterations: 0.0001815434429373729
# Loss after 7350 iterations: 0.00018096197670939334
# Loss after 7400 iterations: 0.00017874967576499465
# Loss after 7450 iterations: 0.000173243552752537
# Loss after 7500 iterations: 0.0001704408036911807
# Loss after 7550 iterations: 0.00015624880765042034
# Loss after 7600 iterations: 0.000151255256194585
# Loss after 7650 iterations: 0.00014932744794737975
# Loss after 7700 iterations: 0.00014750536985270676
# Loss after 7750 iterations: 0.00014739074560757
# Loss after 7800 iterations: 0.00014685178272551955
# Loss after 7850 iterations: 0.00014621174262532358
# Loss after 7900 iterations: 0.0001457985593017218
# Loss after 7950 iterations: 0.0001448902338208613
# Loss after 8000 iterations: 0.0001442337993144879
# Loss after 8050 iterations: 0.00014400169098314325
# Loss after 8100 iterations: 0.0001433528462746892
# Loss after 8150 iterations: 0.00014257238630465568
# Loss after 8200 iterations: 0.00014205693050676484
# Loss after 8250 iterations: 0.00014086201072339652
# Loss after 8300 iterations: 0.0001400630602090522
# Loss after 8350 iterations: 0.00013954430953346818
# Loss after 8400 iterations: 0.00013934728682063786
# Loss after 8450 iterations: 0.00013851366315515665
# Loss after 8500 iterations: 0.00013839263484833806
# Loss after 8550 iterations: 0.00013814993717196973
# Loss after 8600 iterations: 0.00013810922393711235
# Loss after 8650 iterations: 0.00013808308613971035
# Loss after 8700 iterations: 0.00013792471207745466
# Loss after 8750 iterations: 0.00013786089763216048
# Loss after 8800 iterations: 0.0001375867968347203
# Loss after 8850 iterations: 0.00013756273553387915
# Loss after 8900 iterations: 0.0001375001939778046
# Loss after 8950 iterations: 0.0001374666848927466
# Loss after 9000 iterations: 0.00013739021964277146
# Loss after 9050 iterations: 0.00013707995165152805
# Loss after 9100 iterations: 0.0001364913099027757
# Loss after 9150 iterations: 0.00013593578622449478
# Loss after 9200 iterations: 0.00013579555000431916
# Loss after 9250 iterations: 0.00013577020799354186
# Loss after 9300 iterations: 0.00013567270765759746
# Loss after 9350 iterations: 0.00013564690657484285
# Loss after 9400 iterations: 0.00013563057938845095
# Loss after 9450 iterations: 0.00013560715860383972
# Loss after 9500 iterations: 0.0001354264466070941
# Loss after 9550 iterations: 0.00013534218536933156
# Loss after 9600 iterations: 0.00013530879384325925
# Loss after 9650 iterations: 0.00013529360043439294
# Loss after 9700 iterations: 0.00013525680862301465
# Loss after 9750 iterations: 0.0001351651740871015
# Loss after 9800 iterations: 0.00013512973027958523
# Loss after 9850 iterations: 0.00013503359200321298
# Loss after 9900 iterations: 0.0001349911887601768
# Loss after 9950 iterations: 0.0001349755243652638
# Loss after 10000 iterations: 0.00013495386779348244

# %% [markdown]
# ### Visualize the results

# %%
plot(1:5000, losses[1:5000], yaxis=:log10, xlabel="Iterations", ylabel="Loss", label="ADAM", color=:blue)
plot!(5001:length(losses), losses[5001:end], yaxis=:log10, label="BFGS", color=:red)

# %%
X̂ = predict(p_trained, t)
plot(t, X̂', xlabel = "Time", ylabel = "Number of individuals", color = [:blue :goldenrod2 :magenta :green],
     label = ["UDE approximation" nothing nothing nothing])
scatter!(t[begin:5:end], X_noisy', color = [:blue :goldenrod2 :magenta :green], 
     label = ["Noisy data" nothing nothing nothing])

# %%
plot(t, X', xlabel = "Time", ylabel = "Number of individuals", color = [:blue :goldenrod2 :magenta :green], 
     label = ["True trajectory" nothing nothing nothing])
plot!(t, X̂', color = [:blue :goldenrod2 :magenta :green], linestyle = :dash, 
     label = ["UDE approximation" nothing nothing nothing])

# %%
# True residual dynamics (i.e. interactions of predictors) along the true trajectory
dynamics_true = [-β/N*(X[1,:].*X[3,:])'; β/N*(X[1,:].*X[3,:])'-α*X[2,:]'; α*X[2,:]'; zeros(length(t))']
# Neural network guess along the true trajectory
dynamics_nn = Lux.apply(model, X, p_trained, st)[1]

plot(t, dynamics_true', xlabel = "Time", ylabel = "Residual dynamics", color = [:blue :goldenrod2 :magenta :green], 
     label = ["True" nothing nothing nothing])
plot!(t, dynamics_nn', color = [:blue :goldenrod2 :magenta :green], linestyle = :dash, 
     label = ["NN(S,E,I,R)" nothing nothing nothing])
