# %% [markdown]
# # Universal differential equation for SIR ODE model

# %% [markdown]
# The script provided below is closely based on and inspired by the tutorial available at the following link: https://docs.sciml.ai/Overview/stable/showcase/missing_physics/

# %%
# SciML Tools
using OrdinaryDiffEq, SciMLSensitivity, Optimization, OptimizationOptimisers, OptimizationOptimJL

# Standard Libraries
using LinearAlgebra, Statistics, Random, Distributions

# External Libraries
using ComponentArrays, Lux, Zygote, Plots, StableRNGs
gr()

# Set a random seed for reproducible behaviour
rng = StableRNG(1111);

# %% [markdown]
# ### Define the SIR dynamics and solve the ODE

# %%
function sir!(du, u, p, t)
    β, γ, N = p
    du[1] = -β*u[1]*u[2]/N
    du[2] = β*u[1]*u[2]/N - γ*u[2]
    du[3] = γ*u[2]
end

p_ODE = [0.6, 0.3, 1.0]
u0 = [0.999, 0.001, 0.0]
tspan = (0.0, 40.0);

# %%
prob = ODEProblem(sir!, u0, tspan, p_ODE)
sol = solve(prob, Tsit5(), abstol = 1e-12, reltol = 1e-12, saveat = 1.0);

# %%
plot(sol, xlabel = "Time", ylabel = "Number of individuals", labels = ["S" "I" "R"])

# %% [markdown]
# ### Add multiplicative log-normal noise

# %%
t = sol.t
X = Array(sol)
dist = LogNormal(0, 0.01)
noise = rand(rng, dist, size(X))
X_noisy = noise .* X;

# %%
plot(t, X', xlabel = "Time", ylabel = "Number of individuals",
     color = :black, label=["True trajectory" nothing nothing])
scatter!(t, X_noisy', color = :red, label=["Noisy data" nothing nothing])

# %% [markdown]
# ### Set up the UDE

# %% [markdown]
# We set up our UDE by first defining the NN component and then the hybrid model $u'=f(u)+\text{NN}(u)$.

# %%
# Define activation function
rbf(x) = exp.(-(x .^ 2))   

# Multi-layer feed-forward neural network
model = Chain(Dense(3, 5, rbf), Dense(5, 5, rbf), Dense(5, 5, rbf), Dense(5, 3))

# Get initial parameters and state variables of the model
p_init, st = Lux.setup(rng, model);

# %%
# Define the hybrid model
β, γ, N = p_ODE

function ude_dynamics!(du, u, p, t)
    nn = Lux.apply(model, u, p, st)[1]   # Network prediction    
    du[1] = nn[1]
    du[2] = -γ*u[2] + nn[2] 
    du[3] = γ*u[2] + nn[3]
end

prob_ude = ODEProblem(ude_dynamics!, u0, tspan, p_init);

# %% [markdown]
# ### Set up the training

# %%
function predict(p)   # p is the parameter of the NN and the ODE at the same time
    _prob = remake(prob_ude, p=p)
    Array(solve(_prob, Tsit5(), abstol = 1e-6, reltol = 1e-6, saveat = t,
                sensealg=QuadratureAdjoint(autojacvec=ReverseDiffVJP(true))))
end;

# %%
function loss(p)
    X̂ = predict(p)
    mean(abs2, X_noisy .- X̂)   # MSE loss
end;

# %%
losses = Float64[]

function callback(p, l)
    push!(losses, l)
    n_iter = length(losses)
    if n_iter % 50 == 0   
        println("Loss after $(n_iter) iterations: $(losses[end])")
    end
    return false
end;

# %% [markdown]
# ### Train the UDE

# %%
adtype = AutoZygote()   # automatic differentiation
optf = OptimizationFunction((p, _) -> loss(p), adtype)
optprob = OptimizationProblem(optf, ComponentVector{Float64}(p_init));

# %%
res1 = solve(optprob, ADAM(), callback = callback, maxiters = 5000);
# Out:
# Loss after 50 iterations: 1.818564524606704
# Loss after 100 iterations: 0.9998842059923964
# Loss after 150 iterations: 0.5996383157469011
# Loss after 200 iterations: 0.3542130799156783
# Loss after 250 iterations: 0.21764730572439295
# Loss after 300 iterations: 0.14182610287354422
# Loss after 350 iterations: 0.0975911779822014
# Loss after 400 iterations: 0.07016788413700817
# Loss after 450 iterations: 0.05222287512671537
# Loss after 500 iterations: 0.03995743637586214
# Loss after 550 iterations: 0.03128572426127433
# Loss after 600 iterations: 0.024993804054220303
# Loss after 650 iterations: 0.020336421022996133
# Loss after 700 iterations: 0.016834395258297545
# Loss after 750 iterations: 0.014167647133733412
# Loss after 800 iterations: 0.01211572847439477
# Loss after 850 iterations: 0.01052301141843371
# Loss after 900 iterations: 0.009277377541161388
# Loss after 950 iterations: 0.008296667380129378
# Loss after 1000 iterations: 0.007519812296464193
# Loss after 1050 iterations: 0.006900862867454511
# Loss after 1100 iterations: 0.006404910547471303
# Loss after 1150 iterations: 0.0060052246956027264
# Loss after 1200 iterations: 0.005681202091005707
# Loss after 1250 iterations: 0.0054168917938972475
# Loss after 1300 iterations: 0.005199897699564703
# Loss after 1350 iterations: 0.005020559464956761
# Loss after 1400 iterations: 0.004871332698320592
# Loss after 1450 iterations: 0.004746314680245487
# Loss after 1500 iterations: 0.004640877675166085
# Loss after 1550 iterations: 0.004551384760529989
# Loss after 1600 iterations: 0.0044749697521788
# Loss after 1650 iterations: 0.004409365057717788
# Loss after 1700 iterations: 0.004352767588673272
# Loss after 1750 iterations: 0.004303734454115711
# Loss after 1800 iterations: 0.0042611020296187425
# Loss after 1850 iterations: 0.0042239233693666094
# Loss after 1900 iterations: 0.004191420006468036
# Loss after 1950 iterations: 0.0041629449995860025
# Loss after 2000 iterations: 0.004137954726608045
# Loss after 2050 iterations: 0.004115987439347313
# Loss after 2100 iterations: 0.004096647000875337
# Loss after 2150 iterations: 0.004079590566596945
# Loss after 2200 iterations: 0.004064519235758436
# Loss after 2250 iterations: 0.004051170915843702
# Loss after 2300 iterations: 0.004039314829527758
# Loss after 2350 iterations: 0.0040287472243776224
# Loss after 2400 iterations: 0.004019287958126416
# Loss after 2450 iterations: 0.004010777724994966
# Loss after 2500 iterations: 0.004003075734615652
# Loss after 2550 iterations: 0.003996057748013591
# Loss after 2600 iterations: 0.003989614364895919
# Loss after 2650 iterations: 0.003983649497228452
# Loss after 2700 iterations: 0.003978078997593485
# Loss after 2750 iterations: 0.003972829418431091
# Loss after 2800 iterations: 0.003967836876187599
# Loss after 2850 iterations: 0.003963046013197996
# Loss after 2900 iterations: 0.003958409043249343
# Loss after 2950 iterations: 0.003953884876295001
# Loss after 3000 iterations: 0.003949438318948211
# Loss after 3050 iterations: 0.003945039345626101
# Loss after 3100 iterations: 0.003940662436616121
# Loss after 3150 iterations: 0.003936285979808541
# Loss after 3200 iterations: 0.003931891732279969
# Loss after 3250 iterations: 0.003927464338760823
# Loss after 3300 iterations: 0.0039229909030506745
# Loss after 3350 iterations: 0.003918460608888336
# Loss after 3400 iterations: 0.003913864386898733
# Loss after 3450 iterations: 0.0039091946237888656
# Loss after 3500 iterations: 0.003904444910286113
# Loss after 3550 iterations: 0.0038996098239610583
# Loss after 3600 iterations: 0.00389468474381137
# Loss after 3650 iterations: 0.0038896656930019315
# Loss after 3700 iterations: 0.0038845492064578956
# Loss after 3750 iterations: 0.0038793322203932814
# Loss after 3800 iterations: 0.003874011980763808
# Loss after 3850 iterations: 0.003868585967979003
# Loss after 3900 iterations: 0.0038630518354225256
# Loss after 3950 iterations: 0.003857407359821456
# Loss after 4000 iterations: 0.003851650400975437
# Loss after 4050 iterations: 0.003845778869539864
# Loss after 4100 iterations: 0.0038397907013016145
# Loss after 4150 iterations: 0.003833683836516469
# Loss after 4200 iterations: 0.003827456203367365
# Loss after 4250 iterations: 0.003821105704371999
# Loss after 4300 iterations: 0.0038146302052956046
# Loss after 4350 iterations: 0.003808027525756212
# Loss after 4400 iterations: 0.003801295430977624
# Loss after 4450 iterations: 0.0037944316245677612
# Loss after 4500 iterations: 0.00378743374154455
# Loss after 4550 iterations: 0.003780299341841499
# Loss after 4600 iterations: 0.003773025903798242
# Loss after 4650 iterations: 0.0037656108175258968
# Loss after 4700 iterations: 0.0037580513781841664
# Loss after 4750 iterations: 0.003750344778922216
# Loss after 4800 iterations: 0.0037424881032962674
# Loss after 4850 iterations: 0.003734478317478524
# Loss after 4900 iterations: 0.0037263122618823767
# Loss after 4950 iterations: 0.0037179866423297453
# Loss after 5000 iterations: 0.0037094980205900144

# %%
optprob2 = OptimizationProblem(optf, res1.u)
res2 = solve(optprob2, LBFGS(), callback = callback, maxiters = 1000)
p_trained = res2.u;
# Out:
# Loss after 5050 iterations: 0.002390621883734631
# Loss after 5100 iterations: 0.0017249368994395613
# Loss after 5150 iterations: 0.0002910932934275128
# Loss after 5200 iterations: 4.161913124624974e-5
# Loss after 5250 iterations: 3.009919675133652e-5
# Loss after 5300 iterations: 2.8149848324796302e-5
# Loss after 5350 iterations: 2.6396929669162595e-5
# Loss after 5400 iterations: 2.5904637255488607e-5
# Loss after 5450 iterations: 2.5588434333520473e-5
# Loss after 5500 iterations: 2.546524252334161e-5
# Loss after 5550 iterations: 2.542173878175475e-5
# Loss after 5600 iterations: 2.5335696281617053e-5
# Loss after 5650 iterations: 2.5225126762374936e-5
# Loss after 5700 iterations: 2.4506022836698307e-5
# Loss after 5750 iterations: 2.3616134252296287e-5
# Loss after 5800 iterations: 2.302210046937115e-5
# Loss after 5850 iterations: 2.2424183943413026e-5
# Loss after 5900 iterations: 2.2211976853026547e-5
# Loss after 5950 iterations: 2.199563921039671e-5
# Loss after 6000 iterations: 2.1653404215040655e-5

# %% [markdown]
# ### Visualize the results

# %%
plot(1:5000, losses[1:5000], yaxis=:log10, xlabel="Iterations", ylabel="Loss", label="ADAM", color=:blue)
plot!(5001:length(losses), losses[5001:end], yaxis=:log10, label="BFGS", color = :red)

# %%
X̂ = predict(p_trained)
plot(t, X̂', xlabel = "Time", ylabel = "Number of individuals", color = :black,
     label = ["UDE approximation" nothing nothing])
scatter!(t, X_noisy', color = :red, label=["Noisy data" nothing nothing])

# %%
plot(t, X̂', xlabel = "Time", ylabel = "Number of individuals", color = :black,
     label = ["UDE approximation" nothing nothing])
plot!(t, X', color = :red, linestyle=:dash, label=["True trajectory" nothing nothing])

# %%
# True residual dynamics (i.e. interactions of predictors) along the true trajectory
dynamics_true = [-β/N * (X[1, :] .* X[2, :])'; β/N * (X[1, :] .* X[2, :])'; zeros(length(t))']
# Neural network guess along the approximated trajectory
dynamics_nn = Lux.apply(model, X̂, p_trained, st)[1]

plot(t, dynamics_nn', xlabel = "Time", ylabel = "Residual dynamics", color = :black,
     label = ["NN(S,I,R)" nothing nothing])
plot!(t, dynamics_true', color = :red, linestyle=:dash, label = ["True" nothing nothing])
