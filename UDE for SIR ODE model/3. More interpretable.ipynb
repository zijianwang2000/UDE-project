# %% [markdown]
# # Universal differential equation for SIR ODE model

# %% [markdown]
# The script provided below is closely based on and inspired by the tutorial available at the following link: https://docs.sciml.ai/Overview/stable/showcase/missing_physics/

# %%
# SciML Tools
using OrdinaryDiffEq, SciMLSensitivity, Optimization, OptimizationOptimisers, OptimizationOptimJL

# Standard Libraries
using LinearAlgebra, Statistics, Random, Distributions

# External Libraries
using ComponentArrays, Lux, Zygote, Plots, StableRNGs
gr()

# Set a random seed for reproducible behaviour
rng = StableRNG(1111);

# %% [markdown]
# ### Define the SIR dynamics and solve the ODE

# %%
function sir!(du, u, p, t)
    β, γ, N = p
    du[1] = -β*u[1]*u[2]/N
    du[2] = β*u[1]*u[2]/N - γ*u[2]
    du[3] = γ*u[2]
end

p_ODE = [0.6, 0.3, 1.0]
u0 = [0.999, 0.001, 0.0]
tspan = (0.0, 40.0);

# %%
prob = ODEProblem(sir!, u0, tspan, p_ODE)
sol = solve(prob, Tsit5(), abstol = 1e-12, reltol = 1e-12, saveat = 1.0);

# %%
plot(sol, xlabel = "Time", ylabel = "Number of individuals", labels = ["S" "I" "R"])

# %% [markdown]
# ### Add multiplicative log-normal noise

# %%
t = sol.t
X = Array(sol)
dist = LogNormal(0, 0.01)
noise = rand(rng, dist, size(X))
X_noisy = noise .* X;

# %%
plot(t, X', xlabel = "Time", ylabel = "Number of individuals",
     color = :black, label=["True trajectory" nothing nothing])
scatter!(t, X_noisy', color = :red, label=["Noisy data" nothing nothing])

# %% [markdown]
# ### Set up the UDE

# %% [markdown]
# We set up our UDE by first defining the NN component and then the hybrid model $u'=f(u)+\text{NN}(u)$.

# %%
# Define activation function
rbf(x) = exp.(-(x .^ 2))   

# Multi-layer feed-forward neural network
model = Chain(Dense(2, 5, rbf), Dense(5, 5, rbf), Dense(5, 2))

# Get initial parameters and state variables of the model
p_init, st = Lux.setup(rng, model);

# %%
# Define the hybrid model
β, γ, N = p_ODE

function ude_dynamics!(du, u, p, t)
    nn = Lux.apply(model, u[1:2], p, st)[1]   # Network prediction    
    du[1] = nn[1]
    du[2] = -γ*u[2] + nn[2] 
    du[3] = γ*u[2]
end

prob_ude = ODEProblem(ude_dynamics!, u0, tspan, p_init);

# %% [markdown]
# ### Set up the training

# %%
function predict(p)   # p is the parameter of the NN and the ODE at the same time
    _prob = remake(prob_ude, p=p)
    Array(solve(_prob, Tsit5(), abstol = 1e-6, reltol = 1e-6, saveat = t,
                sensealg=QuadratureAdjoint(autojacvec=ReverseDiffVJP(true))))
end;

# %%
function loss(p)
    X̂ = predict(p)
    mean(abs2, X_noisy .- X̂)   # MSE loss
end;

# %%
losses = Float64[]

function callback(p, l)
    push!(losses, l)
    n_iter = length(losses)
    if n_iter % 50 == 0   
        println("Loss after $(n_iter) iterations: $(losses[end])")
    end
    return false
end;

# %% [markdown]
# ### Train the UDE

# %%
adtype = AutoZygote()   # automatic differentiation
optf = OptimizationFunction((p, _) -> loss(p), adtype)
optprob = OptimizationProblem(optf, ComponentVector{Float64}(p_init));

# %%
res1 = solve(optprob, ADAM(), callback = callback, maxiters = 5000);
# Out:
# Loss after 50 iterations: 104.27279683439237
# Loss after 100 iterations: 5.012033078772849
# Loss after 150 iterations: 0.599550574954219
# Loss after 200 iterations: 0.4100921703627508
# Loss after 250 iterations: 0.3154053138645215
# Loss after 300 iterations: 0.24023568903483317
# Loss after 350 iterations: 0.1706832803346107
# Loss after 400 iterations: 0.1059677492003052
# Loss after 450 iterations: 0.06455249678048966
# Loss after 500 iterations: 0.04633801857000506
# Loss after 550 iterations: 0.03726581642006081
# Loss after 600 iterations: 0.031959231578796155
# Loss after 650 iterations: 0.028586670896558017
# Loss after 700 iterations: 0.026236684923120892
# Loss after 750 iterations: 0.024372568154313042
# Loss after 800 iterations: 0.022717143843965497
# Loss after 850 iterations: 0.021161885039417336
# Loss after 900 iterations: 0.01967932183197638
# Loss after 950 iterations: 0.0182692906335453
# Loss after 1000 iterations: 0.016936825890344048
# Loss after 1050 iterations: 0.01568599983618743
# Loss after 1100 iterations: 0.014519008177517369
# Loss after 1150 iterations: 0.013436364371032308
# Loss after 1200 iterations: 0.012437188837899163
# Loss after 1250 iterations: 0.011519465591682815
# Loss after 1300 iterations: 0.010680273861663453
# Loss after 1350 iterations: 0.009915998235274257
# Loss after 1400 iterations: 0.009222521920741083
# Loss after 1450 iterations: 0.008595396339566906
# Loss after 1500 iterations: 0.00802997701467495
# Loss after 1550 iterations: 0.007521558325430615
# Loss after 1600 iterations: 0.007065466754777998
# Loss after 1650 iterations: 0.006657140899624847
# Loss after 1700 iterations: 0.006292190595788741
# Loss after 1750 iterations: 0.005966447793051956
# Loss after 1800 iterations: 0.005675980484091065
# Loss after 1850 iterations: 0.00541712620757782
# Loss after 1900 iterations: 0.005186493847758606
# Loss after 1950 iterations: 0.00498096498598199
# Loss after 2000 iterations: 0.004797689766239514
# Loss after 2050 iterations: 0.004634077713802099
# Loss after 2100 iterations: 0.004487786563848406
# Loss after 2150 iterations: 0.004356712891731596
# Loss after 2200 iterations: 0.004238964528747629
# Loss after 2250 iterations: 0.004132860328675356
# Loss after 2300 iterations: 0.004036907086255334
# Loss after 2350 iterations: 0.003949785693877041
# Loss after 2400 iterations: 0.0038703365070060242
# Loss after 2450 iterations: 0.00379754509371888
# Loss after 2500 iterations: 0.003730527019749532
# Loss after 2550 iterations: 0.0036685244592818186
# Loss after 2600 iterations: 0.0036108742941042492
# Loss after 2650 iterations: 0.003557016196144732
# Loss after 2700 iterations: 0.0035064725602877694
# Loss after 2750 iterations: 0.0034588397010017324
# Loss after 2800 iterations: 0.0034137787004231914
# Loss after 2850 iterations: 0.0033710066530351925
# Loss after 2900 iterations: 0.003330288323641284
# Loss after 2950 iterations: 0.003291429358199871
# Loss after 3000 iterations: 0.003254268636208879
# Loss after 3050 iterations: 0.00321867246362737
# Loss after 3100 iterations: 0.003184529847258133
# Loss after 3150 iterations: 0.0031517479023151747
# Loss after 3200 iterations: 0.0031202435750991944
# Loss after 3250 iterations: 0.0030899460648323852
# Loss after 3300 iterations: 0.0030607903148495335
# Loss after 3350 iterations: 0.0030327150962106827
# Loss after 3400 iterations: 0.0030056608633779636
# Loss after 3450 iterations: 0.0029795684511035587
# Loss after 3500 iterations: 0.0029543779811419075
# Loss after 3550 iterations: 0.002930027484465926
# Loss after 3600 iterations: 0.0029064543755591807
# Loss after 3650 iterations: 0.0028835902662220827
# Loss after 3700 iterations: 0.00286136688428514
# Loss after 3750 iterations: 0.0028397125689094147
# Loss after 3800 iterations: 0.002818554037801483
# Loss after 3850 iterations: 0.0027978161956974936
# Loss after 3900 iterations: 0.0027774219823006436
# Loss after 3950 iterations: 0.002757293849210134
# Loss after 4000 iterations: 0.002737353767603948
# Loss after 4050 iterations: 0.0027175242952543863
# Loss after 4100 iterations: 0.0026977273495026317
# Loss after 4150 iterations: 0.0026778863765250975
# Loss after 4200 iterations: 0.0026579264180049567
# Loss after 4250 iterations: 0.002637773936834543
# Loss after 4300 iterations: 0.00261735679979122
# Loss after 4350 iterations: 0.002596605132657068
# Loss after 4400 iterations: 0.0025754514102310643
# Loss after 4450 iterations: 0.0025538303791710192
# Loss after 4500 iterations: 0.002531679134288138
# Loss after 4550 iterations: 0.002508937134010994
# Loss after 4600 iterations: 0.002485546178653939
# Loss after 4650 iterations: 0.0024614503648572456
# Loss after 4700 iterations: 0.0024365960219676244
# Loss after 4750 iterations: 0.0024109316420892627
# Loss after 4800 iterations: 0.002384407811344989
# Loss after 4850 iterations: 0.0023569771529589945
# Loss after 4900 iterations: 0.002328594295324233
# Loss after 4950 iterations: 0.002299215861129549
# Loss after 5000 iterations: 0.002268800501743524

# %%
optprob2 = OptimizationProblem(optf, res1.u)
res2 = solve(optprob2, LBFGS(), callback = callback, maxiters = 1000)
p_trained = res2.u;
# Out:
# Loss after 5050 iterations: 0.00019289758961004978
# Loss after 5100 iterations: 7.709723924500529e-5
# Loss after 5150 iterations: 4.2370187651937374e-5
# Loss after 5200 iterations: 3.635178267328103e-5
# Loss after 5250 iterations: 3.078929042130865e-5
# Loss after 5300 iterations: 2.7052620885418262e-5
# Loss after 5350 iterations: 2.5376178619615818e-5
# Loss after 5400 iterations: 2.4195389928203636e-5
# Loss after 5450 iterations: 2.3049021972809957e-5
# Loss after 5500 iterations: 2.2601081221729726e-5
# Loss after 5550 iterations: 2.2502391637317495e-5
# Loss after 5600 iterations: 2.2304798997865756e-5
# Loss after 5650 iterations: 2.2184295820830095e-5
# Loss after 5700 iterations: 2.216514394796635e-5
# Loss after 5750 iterations: 2.214756587579159e-5
# Loss after 5800 iterations: 2.2141372552119187e-5
# Loss after 5850 iterations: 2.213943456529374e-5
# Loss after 5900 iterations: 2.213820370209158e-5
# Loss after 5950 iterations: 2.2136417101363135e-5
# Loss after 6000 iterations: 2.2135018747676697e-5

# %% [markdown]
# ### Visualize the results

# %%
plot(1:5000, losses[1:5000], yaxis=:log10, xlabel="Iterations", ylabel="Loss", label="ADAM", color=:blue)
plot!(5001:length(losses), losses[5001:end], yaxis=:log10, label="BFGS", color = :red)

# %%
X̂ = predict(p_trained)
plot(t, X̂', xlabel = "Time", ylabel = "Number of individuals", color = :black,
     label = ["UDE approximation" nothing nothing])
scatter!(t, X_noisy', color = :red, label=["Noisy data" nothing nothing])

# %%
plot(t, X̂', xlabel = "Time", ylabel = "Number of individuals", color = :black,
     label = ["UDE approximation" nothing nothing])
plot!(t, X', color = :red, linestyle=:dash, label=["True trajectory" nothing nothing])

# %%
# True residual dynamics (i.e. interactions of predictors) along the true trajectory
dynamics_true = [-β/N * (X[1, :] .* X[2, :])'; β/N * (X[1, :] .* X[2, :])']
# Neural network guess along the approximated trajectory
dynamics_nn = Lux.apply(model, X̂[1:2, :], p_trained, st)[1]

plot(t, dynamics_nn', xlabel = "Time", ylabel = "Residual dynamics", color = :black, label = ["NN(S,I)" nothing])
plot!(t, dynamics_true', color = :red, linestyle=:dash, label = ["True" nothing])

# %% [markdown]
# We can also check how well the approximation of residual dynamics generalizes from the true trajectory to the rest of the domain.

# %%
s = range(0.0, stop=1.0, length=100)
i = range(0.0, stop=0.5, length=100)
grid = Iterators.product(s, i)

error_1(s, i) = abs(-β*s*i/N - Lux.apply(model, [s, i], p_trained, st)[1][1])
errors_1 = [error_1(sk, ik) for (sk, ik) in grid]
error_2(s, i) = abs(β*s*i/N - Lux.apply(model, [s, i], p_trained, st)[1][2])
errors_2 = [error_2(sk, ik) for (sk, ik) in grid]
clims = (0, max(maximum(errors_1), maximum(errors_2)));

# %%
heatmap(s, i, errors_1', clims=clims, xlabel="S", ylabel="I", title="\$|Res_1(S,I)-NN_1(S,I)|\$")
scatter!(X[1, :], X[2, :], label="Trajectory", color=:grey)

# %%
heatmap(s, i, errors_2', clims=clims, xlabel="S", ylabel="I", title="\$|Res_2(S,I)-NN_2(S,I)|\$")
scatter!(X[1, :], X[2, :], label="Trajectory", color=:grey)
