# %% [markdown]
# # Universal differential equation for SIR ODE model

# %% [markdown]
# In this notebook, we want to jointly estimate the parameter $\gamma$ of the known part of the mechanistic model and the parameters $\theta$ of the neural network, which is supposed to learn the unknown residual dynamics.

# %%
# SciML Tools
using OrdinaryDiffEq, SciMLSensitivity, Optimization, OptimizationOptimisers, OptimizationOptimJL

# Standard Libraries
using LinearAlgebra, Statistics, Random, Distributions

# External Libraries
using ComponentArrays, Lux, Zygote, Plots, StableRNGs
gr()

# Set a random seed for reproducible behaviour
rng = StableRNG(1111);

# %% [markdown]
# ### Define the SIR dynamics and solve the ODE

# %%
function sir!(du, u, p, t)
    β, γ, N = p
    du[1] = -β*u[1]*u[2]/N
    du[2] = β*u[1]*u[2]/N - γ*u[2]
    du[3] = γ*u[2]
end

p_ODE = [0.6, 0.3, 1.0]
u0 = [0.999, 0.001, 0.0]
tspan = (0.0, 40.0);

# %%
prob = ODEProblem(sir!, u0, tspan, p_ODE)
sol = solve(prob, Tsit5(), abstol = 1e-12, reltol = 1e-12, saveat = 1.0);

# %%
plot(sol, xlabel = "Time", ylabel = "Number of individuals", labels = ["S" "I" "R"])

# %% [markdown]
# ### Add multiplicative log-normal noise

# %%
t = sol.t
X = Array(sol)
dist = LogNormal(0, 0.01)
noise = rand(rng, dist, size(X))
X_noisy = noise .* X;

# %%
plot(t, X', xlabel = "Time", ylabel = "Number of individuals",
     color = :black, label=["True trajectory" nothing nothing])
scatter!(t, X_noisy', color = :red, label=["Noisy data" nothing nothing])

# %% [markdown]
# ### Set up the UDE

# %% [markdown]
# We set up our UDE by first defining the NN component and then the hybrid model $u'=f(u, \gamma)+\text{NN}(u, \theta)$.

# %%
# Define activation function
rbf(x) = exp.(-(x .^ 2))

# Multi-layer feed-forward neural network
model = Chain(Dense(3, 5, rbf), Dense(5, 5, rbf), Dense(5, 5, rbf), Dense(5, 3))

# Get initial parameters and state variables of the model
θ_init, st = Lux.setup(rng, model);

# %%
# Define the hybrid model
β, γ, N = p_ODE

function ude_dynamics!(du, u, p, t)
    nn = Lux.apply(model, u, p.nn, st)[1]   # Network prediction    
    du[1] = nn[1]
    du[2] = -p.γ*u[2] + nn[2] 
    du[3] = p.γ*u[2] + nn[3]
end

γ_init = 0.1
p_init = (nn = θ_init, γ = γ_init)
p_init = ComponentVector(p_init)
prob_ude = ODEProblem(ude_dynamics!, u0, tspan, p_init);

# %%
sol_ude_init = solve(prob_ude, Tsit5(), abstol = 1e-6, reltol = 1e-6, saveat = t)
plot(sol_ude_init, xlabel = "Time", ylabel = "Number of individuals", labels = ["S" "I" "R"])

# %% [markdown]
# ### Set up the training

# %%
function predict(p)   # p consists of the NN parameters θ and the mechanistic parameter γ of the ODE
    _prob = remake(prob_ude, p=p)
    Array(solve(_prob, Tsit5(), abstol = 1e-6, reltol = 1e-6, saveat = t,
                sensealg=QuadratureAdjoint(autojacvec=ReverseDiffVJP(true))))
end;

# %%
function loss(p)
    X̂ = predict(p)
    mean(abs2, X_noisy .- X̂)   # MSE loss
end;

# %%
losses = Float64[]

function callback(p, l)
    push!(losses, l)
    n_iter = length(losses)
    if n_iter % 50 == 0   
        println("Loss after $(n_iter) iterations: $(losses[end])")
    end
    return false
end;

# %% [markdown]
# ### Train the UDE

# %%
adtype = AutoZygote()   # automatic differentiation
optf = OptimizationFunction((p, _) -> loss(p), adtype)
optprob = OptimizationProblem(optf, p_init);

# %%
res1 = solve(optprob, ADAM(), callback = callback, maxiters = 5000);
# Out:
# Loss after 50 iterations: 1.2246248174757788
# Loss after 100 iterations: 0.23757049670752384
# Loss after 150 iterations: 0.07849239474464356
# Loss after 200 iterations: 0.03308438845600604
# Loss after 250 iterations: 0.017035074334555877
# Loss after 300 iterations: 0.010655011692055204
# Loss after 350 iterations: 0.007848124909513204
# Loss after 400 iterations: 0.006469995021872162
# Loss after 450 iterations: 0.005716180387744477
# Loss after 500 iterations: 0.0052651013214190705
# Loss after 550 iterations: 0.00497553317110734
# Loss after 600 iterations: 0.004778267971540815
# Loss after 650 iterations: 0.004636308661300343
# Loss after 700 iterations: 0.004528894714743704
# Loss after 750 iterations: 0.004444099578900669
# Loss after 800 iterations: 0.004374935688334629
# Loss after 850 iterations: 0.004317176180440564
# Loss after 900 iterations: 0.004268126394876705
# Loss after 950 iterations: 0.004225945305073542
# Loss after 1000 iterations: 0.004189282069848793
# Loss after 1050 iterations: 0.004157085634349503
# Loss after 1100 iterations: 0.004128507162994775
# Loss after 1150 iterations: 0.004102847500608737
# Loss after 1200 iterations: 0.004079527786967092
# Loss after 1250 iterations: 0.004058069684525081
# Loss after 1300 iterations: 0.004038080251768643
# Loss after 1350 iterations: 0.004019239714563226
# Loss after 1400 iterations: 0.004001290278783535
# Loss after 1450 iterations: 0.003984026214213492
# Loss after 1500 iterations: 0.0039672851789281606
# Loss after 1550 iterations: 0.0039509405451041
# Loss after 1600 iterations: 0.003934894798763335
# Loss after 1650 iterations: 0.003919073721518013
# Loss after 1700 iterations: 0.0039034215286819175
# Loss after 1750 iterations: 0.0038878967743002707
# Loss after 1800 iterations: 0.003872468957032271
# Loss after 1850 iterations: 0.0038571157325893615
# Loss after 1900 iterations: 0.003841820658763368
# Loss after 1950 iterations: 0.003826571436076664
# Loss after 2000 iterations: 0.0038113584571322972
# Loss after 2050 iterations: 0.0037961737377658665
# Loss after 2100 iterations: 0.0037810101010889363
# Loss after 2150 iterations: 0.003765860575168096
# Loss after 2200 iterations: 0.0037507179569160965
# Loss after 2250 iterations: 0.003735574529984812
# Loss after 2300 iterations: 0.003720421879629893
# Loss after 2350 iterations: 0.0037052507752099798
# Loss after 2400 iterations: 0.0036900511246128246
# Loss after 2450 iterations: 0.0036748119710657994
# Loss after 2500 iterations: 0.0036595215106064063
# Loss after 2550 iterations: 0.0036441671235462217
# Loss after 2600 iterations: 0.003628735437760831
# Loss after 2650 iterations: 0.0036132123922614605
# Loss after 2700 iterations: 0.0035975832925594104
# Loss after 2750 iterations: 0.0035818328666765687
# Loss after 2800 iterations: 0.0035659453164509237
# Loss after 2850 iterations: 0.003549904356228793
# Loss after 2900 iterations: 0.003533693251270323
# Loss after 2950 iterations: 0.0035172948374391816
# Loss after 3000 iterations: 0.00350069153147845
# Loss after 3050 iterations: 0.0034838653311620575
# Loss after 3100 iterations: 0.0034667978039372295
# Loss after 3150 iterations: 0.003449470065564415
# Loss after 3200 iterations: 0.0034318627486097145
# Loss after 3250 iterations: 0.003413955963695753
# Loss after 3300 iterations: 0.0033957292528581534
# Loss after 3350 iterations: 0.0033771615373490832
# Loss after 3400 iterations: 0.0033582310630398677
# Loss after 3450 iterations: 0.003338915342389658
# Loss after 3500 iterations: 0.0033191910997675206
# Loss after 3550 iterations: 0.0032990342170608183
# Loss after 3600 iterations: 0.0032784196874096837
# Loss after 3650 iterations: 0.003257321575845467
# Loss after 3700 iterations: 0.003235712992572638
# Loss after 3750 iterations: 0.0032135660797159224
# Loss after 3800 iterations: 0.0031908520177830716
# Loss after 3850 iterations: 0.003167541051880271
# Loss after 3900 iterations: 0.0031436025452509487
# Loss after 3950 iterations: 0.00311900506224686
# Loss after 4000 iterations: 0.0030937164885137267
# Loss after 4050 iterations: 0.0030677041828386193
# Loss after 4100 iterations: 0.003040935179289041
# Loss after 4150 iterations: 0.0030133764395854955
# Loss after 4200 iterations: 0.0029849951610073826
# Loss after 4250 iterations: 0.002955759146621478
# Loss after 4300 iterations: 0.002925637250897352
# Loss after 4350 iterations: 0.0028945998830789306
# Loss after 4400 iterations: 0.002862619602850997
# Loss after 4450 iterations: 0.0028296718077491967
# Loss after 4500 iterations: 0.0027957354981020576
# Loss after 4550 iterations: 0.0027607941426513716
# Loss after 4600 iterations: 0.003298412161947219
# Loss after 4650 iterations: 0.002702497837791801
# Loss after 4700 iterations: 0.0026641541718835215
# Loss after 4750 iterations: 0.0026311382042056874
# Loss after 4800 iterations: 0.0025970722141640474
# Loss after 4850 iterations: 0.0025621483330559624
# Loss after 4900 iterations: 0.002579609674865594
# Loss after 4950 iterations: 0.0024998959291563628
# Loss after 5000 iterations: 0.0024654244141944365

# %%
optprob2 = OptimizationProblem(optf, res1.u)
res2 = solve(optprob2, LBFGS(), callback = callback, maxiters = 1500)
p_trained = res2.u;
# Out:
# Loss after 5050 iterations: 0.0006350808414309407
# Loss after 5100 iterations: 0.0001147160977818844
# Loss after 5150 iterations: 0.00010136830249264407
# Loss after 5200 iterations: 9.585978074309781e-5
# Loss after 5250 iterations: 6.660969223310876e-5
# Loss after 5300 iterations: 5.294435983402022e-5
# Loss after 5350 iterations: 5.040245941695588e-5
# Loss after 5400 iterations: 4.9061041672921505e-5
# Loss after 5450 iterations: 4.872428704915221e-5
# Loss after 5500 iterations: 3.92125162542823e-5
# Loss after 5550 iterations: 3.54664431445092e-5
# Loss after 5600 iterations: 3.0473272520231792e-5
# Loss after 5650 iterations: 2.7528942818275828e-5
# Loss after 5700 iterations: 2.629266100127389e-5
# Loss after 5750 iterations: 2.605588674537526e-5
# Loss after 5800 iterations: 2.5842677881163296e-5
# Loss after 5850 iterations: 2.5687787382649857e-5
# Loss after 5900 iterations: 2.5603142172903172e-5
# Loss after 5950 iterations: 2.5515565104170884e-5
# Loss after 6000 iterations: 2.5464825777314847e-5
# Loss after 6050 iterations: 2.541379202260265e-5
# Loss after 6100 iterations: 2.5294393509335464e-5
# Loss after 6150 iterations: 2.469338420828687e-5
# Loss after 6200 iterations: 2.4549983863226236e-5
# Loss after 6250 iterations: 2.4438713975026787e-5
# Loss after 6300 iterations: 2.4364899992290612e-5
# Loss after 6350 iterations: 2.431336431076632e-5
# Loss after 6400 iterations: 2.4265493149671055e-5
# Loss after 6450 iterations: 2.4211140006480245e-5
# Loss after 6500 iterations: 2.405387831491282e-5

# %% [markdown]
# ### Visualize the results

# %%
plot(1:5000, losses[1:5000], yaxis=:log10, xlabel="Iterations", ylabel="Loss", label="ADAM", color=:blue)
plot!(5001:length(losses), losses[5001:end], yaxis=:log10, label="BFGS", color = :red)

# %%
X̂ = predict(p_trained)
plot(t, X̂', xlabel = "Time", ylabel = "Number of individuals", color = :black,
     label = ["UDE approximation" nothing nothing])
scatter!(t, X_noisy', color = :red, label=["Noisy data" nothing nothing])

# %%
plot(t, X̂', xlabel = "Time", ylabel = "Number of individuals", color = :black,
     label = ["UDE approximation" nothing nothing])
plot!(t, X', color = :red, linestyle=:dash, label=["True trajectory" nothing nothing])

# %%
p_trained.γ
# Out:
# 0.15609568661544057

# %%
# True residual dynamics (i.e. interactions of predictors) along the true trajectory
dynamics_true = [-β/N * (X[1, :] .* X[2, :])'; β/N * (X[1, :] .* X[2, :])'; zeros(length(t))']
# Neural network guess along the true trajectory
dynamics_nn = Lux.apply(model, X, p_trained.nn, st)[1]

plot(t, dynamics_nn', xlabel = "Time", ylabel = "Residual dynamics", color = :black,
     label = ["NN(S,I,R)" nothing nothing])
plot!(t, dynamics_true', color = :red, linestyle=:dash, label = ["True" nothing nothing])

# %% [markdown]
# The UDE recovers the true trajectory almost perfectly. However, the mechanistic parameter $\gamma$ is under-estimated (initial guess was also too small), and the residual dynamics learned by the NN deviates considerably from the true ones (along the true trajectory). This implies that a part of the effect of the mechanistic model was absorbed by the NN, which is an undesirable behavior.
