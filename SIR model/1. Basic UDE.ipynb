# %% [markdown]
# # Universal differential equation for the SIR model

# %% [markdown]
# The script provided below is closely based on and inspired by the tutorial available at the following link: https://docs.sciml.ai/Overview/stable/showcase/missing_physics/

# %%
# SciML Tools
using OrdinaryDiffEq, SciMLSensitivity, Optimization, OptimizationOptimisers, OptimizationOptimJL

# Standard Libraries
using LinearAlgebra, Statistics, Random, Distributions

# External Libraries
using ComponentArrays, Lux, Zygote, Plots, StableRNGs
gr()

# Set a random seed for reproducible behaviour
rng = StableRNG(1);

# %% [markdown]
# ### Define the SIR dynamics and solve the ODE

# %%
function sir!(du, u, p, t)
    β, γ, N = p
    du[1] = -β*u[1]*u[2]/N
    du[2] = β*u[1]*u[2]/N - γ*u[2]
    du[3] = γ*u[2]
end

p_ODE = [0.6, 0.3, 1.0]
u0 = [0.999, 0.001, 0.0]
tspan = (0.0, 40.0);

# %%
prob = ODEProblem(sir!, u0, tspan, p_ODE)
sol = solve(prob, Tsit5(), abstol = 1e-12, reltol = 1e-12, saveat = 1.0);

# %%
plot(sol, xlabel = "Time", ylabel = "Number of individuals", labels = ["S" "I" "R"], color = [:blue :red :green])

# %% [markdown]
# ### Add multiplicative log-normal noise

# %%
t = sol.t
X = Array(sol)
dist = LogNormal(0, 0.05)
noise = rand(rng, dist, size(X[:, begin:4:end]))
X_noisy = noise .* X[:, begin:4:end];

# %%
plot(t, X', xlabel = "Time", ylabel = "Number of individuals",
     color = [:blue :red :green], label = ["True trajectory" nothing nothing])
scatter!(t[begin:4:end], X_noisy', color = [:blue :red :green], label = ["Noisy data" nothing nothing])

# %% [markdown]
# ### Set up the UDE

# %% [markdown]
# We set up our UDE by first defining the NN component and then the hybrid model $u'=f(u)+\text{NN}(u)$.

# %%
# Define activation function
rbf(x) = exp.(-(x .^ 2))   

# Multi-layer feed-forward neural network
model = Chain(Dense(3, 5, rbf), Dense(5, 5, rbf), Dense(5, 5, rbf), Dense(5, 3))

# Get initial parameters and state variables of the model
p_init, st = Lux.setup(rng, model);

# %%
# Define the hybrid model
β, γ, N = p_ODE

function ude_dynamics!(du, u, p, t)
    nn = Lux.apply(model, u, p, st)[1]   # Network prediction    
    du[1] = nn[1]
    du[2] = -γ*u[2] + nn[2] 
    du[3] = γ*u[2] + nn[3]
end

prob_ude = ODEProblem(ude_dynamics!, u0, tspan, p_init);

# %% [markdown]
# ### Set up the training

# %%
function predict(p, saveat = t[begin:4:end])   # p is the parameter of the NN and the ODE at the same time
    _prob = remake(prob_ude, p = p)
    Array(solve(_prob, Tsit5(), abstol = 1e-6, reltol = 1e-6, saveat = saveat,
                sensealg = QuadratureAdjoint(autojacvec=ReverseDiffVJP(true))))
end;

# %%
function loss(p)
    X̂ = predict(p)
    mean(abs2, X_noisy .- X̂)   # MSE loss
end;

# %%
losses = Float64[]

function callback(p, l)
    push!(losses, l)
    n_iter = length(losses)
    if n_iter % 50 == 0   
        println("Loss after $(n_iter) iterations: $(losses[end])")
    end
    return false
end;

# %% [markdown]
# ### Train the UDE

# %%
adtype = AutoZygote()   # automatic differentiation
optf = OptimizationFunction((p, _) -> loss(p), adtype)
optprob = OptimizationProblem(optf, ComponentVector{Float64}(p_init));

# %%
res1 = solve(optprob, ADAM(), callback = callback, maxiters = 5000);
# Out:
# Loss after 50 iterations: 492.07747313350535
# Loss after 100 iterations: 165.65080362444996
# Loss after 150 iterations: 70.05360542283306
# Loss after 200 iterations: 38.16500041361382
# Loss after 250 iterations: 21.954846982063664
# Loss after 300 iterations: 13.179813769913345
# Loss after 350 iterations: 8.176558106724352
# Loss after 400 iterations: 5.183673951146862
# Loss after 450 iterations: 3.3285299394105166
# Loss after 500 iterations: 2.1471142970656962
# Loss after 550 iterations: 1.379797942680997
# Loss after 600 iterations: 0.8742223612514298
# Loss after 650 iterations: 0.5392011556616203
# Loss after 700 iterations: 0.31914892290001823
# Loss after 750 iterations: 0.17888259534605622
# Loss after 800 iterations: 0.09624746608500348
# Loss after 850 iterations: 0.0531650343090764
# Loss after 900 iterations: 0.03201827797486162
# Loss after 950 iterations: 0.02154669087359491
# Loss after 1000 iterations: 0.01630131916075003
# Loss after 1050 iterations: 0.013673309709919384
# Loss after 1100 iterations: 0.012358459896717659
# Loss after 1150 iterations: 0.011692389803964793
# Loss after 1200 iterations: 0.011338332551351842
# Loss after 1250 iterations: 0.01112884022276594
# Loss after 1300 iterations: 0.010982907228622498
# Loss after 1350 iterations: 0.010862601601018974
# Loss after 1400 iterations: 0.010750795814387558
# Loss after 1450 iterations: 0.010640056971803894
# Loss after 1500 iterations: 0.010527293189526485
# Loss after 1550 iterations: 0.010411272339492319
# Loss after 1600 iterations: 0.010291521259865924
# Loss after 1650 iterations: 0.01016786057560205
# Loss after 1700 iterations: 0.010040221013041232
# Loss after 1750 iterations: 0.009908577045494374
# Loss after 1800 iterations: 0.009772927719892608
# Loss after 1850 iterations: 0.00963329524230259
# Loss after 1900 iterations: 0.009489730232255538
# Loss after 1950 iterations: 0.009342320105507122
# Loss after 2000 iterations: 0.009191198525370895
# Loss after 2050 iterations: 0.009036554871852946
# Loss after 2100 iterations: 0.008878642585798029
# Loss after 2150 iterations: 0.008717793316560397
# Loss after 2200 iterations: 0.008554422032955599
# Loss after 2250 iterations: 0.008389033259937706
# Loss after 2300 iterations: 0.008222227702711566
# Loss after 2350 iterations: 0.008054695675385557
# Loss after 2400 iterations: 0.007887216382049348
# Loss after 2450 iterations: 0.007720640549897462
# Loss after 2500 iterations: 0.007555870534619622
# Loss after 2550 iterations: 0.007393837544307662
# Loss after 2600 iterations: 0.007235469316645332
# Loss after 2650 iterations: 0.007081639765310176
# Loss after 2700 iterations: 0.006933180576355668
# Loss after 2750 iterations: 0.006790807274133028
# Loss after 2800 iterations: 0.006655106325272902
# Loss after 2850 iterations: 0.0065265309140091
# Loss after 2900 iterations: 0.0064053875513891785
# Loss after 2950 iterations: 0.00629182327763495
# Loss after 3000 iterations: 0.006185853156672249
# Loss after 3050 iterations: 0.006087364478245347
# Loss after 3100 iterations: 0.005996131938379502
# Loss after 3150 iterations: 0.005911851898782146
# Loss after 3200 iterations: 0.005834143487966759
# Loss after 3250 iterations: 0.005762580884839389
# Loss after 3300 iterations: 0.005696708590121126
# Loss after 3350 iterations: 0.005636060143022042
# Loss after 3400 iterations: 0.005580145896143031
# Loss after 3450 iterations: 0.005528517751941225
# Loss after 3500 iterations: 0.0054807226158937235
# Loss after 3550 iterations: 0.005436332226494601
# Loss after 3600 iterations: 0.005394944382215709
# Loss after 3650 iterations: 0.005356184115344842
# Loss after 3700 iterations: 0.005319704920345419
# Loss after 3750 iterations: 0.0052851888200148404
# Loss after 3800 iterations: 0.0052523457299549865
# Loss after 3850 iterations: 0.005220912353030737
# Loss after 3900 iterations: 0.005190650700677183
# Loss after 3950 iterations: 0.005161346405225823
# Loss after 4000 iterations: 0.005132806929548547
# Loss after 4050 iterations: 0.005104859769287353
# Loss after 4100 iterations: 0.005077350754067394
# Loss after 4150 iterations: 0.005050141859336421
# Loss after 4200 iterations: 0.005023108017145943
# Loss after 4250 iterations: 0.004996137942766006
# Loss after 4300 iterations: 0.004969135540484136
# Loss after 4350 iterations: 0.004942012752380992
# Loss after 4400 iterations: 0.004914690346777243
# Loss after 4450 iterations: 0.0048870972533884595
# Loss after 4500 iterations: 0.004859169449450395
# Loss after 4550 iterations: 0.0048308490974624235
# Loss after 4600 iterations: 0.004802083617935272
# Loss after 4650 iterations: 0.004772824983594119
# Loss after 4700 iterations: 0.004743028976921631
# Loss after 4750 iterations: 0.00471265458766619
# Loss after 4800 iterations: 0.004681663336859628
# Loss after 4850 iterations: 0.0046500187717182515
# Loss after 4900 iterations: 0.004617685940910561
# Loss after 4950 iterations: 0.004584630897498947
# Loss after 5000 iterations: 0.004550820252031991

# %%
optprob2 = OptimizationProblem(optf, res1.u)
res2 = solve(optprob2, LBFGS(), callback = callback, maxiters = 1500)
p_trained = res2.u;
# Out:
# Loss after 5050 iterations: 0.0011445223498932552
# Loss after 5100 iterations: 0.001019304440107418
# Loss after 5150 iterations: 0.0009308218077389301
# Loss after 5200 iterations: 0.0009052703242232598
# Loss after 5250 iterations: 0.0008659328827937704
# Loss after 5300 iterations: 0.0007975136317771307
# Loss after 5350 iterations: 0.0007339740827825416
# Loss after 5400 iterations: 0.0007237699795067206
# Loss after 5450 iterations: 0.0007100987325683135
# Loss after 5500 iterations: 0.0005331893960602938
# Loss after 5550 iterations: 0.0004967986314617321
# Loss after 5600 iterations: 0.00047477757611141423
# Loss after 5650 iterations: 0.00045583986274352363
# Loss after 5700 iterations: 0.00044761177135039355
# Loss after 5750 iterations: 0.0004221244324403056
# Loss after 5800 iterations: 0.0004177940744895746
# Loss after 5850 iterations: 0.0004091847284625424
# Loss after 5900 iterations: 0.00040155963335962506
# Loss after 5950 iterations: 0.0003993697834672515
# Loss after 6000 iterations: 0.0003968283976040701
# Loss after 6050 iterations: 0.0003870543392976025
# Loss after 6100 iterations: 0.0003834624270019514
# Loss after 6150 iterations: 0.0003814795669126612
# Loss after 6200 iterations: 0.00037793418815958044
# Loss after 6250 iterations: 0.0003746294091039954
# Loss after 6300 iterations: 0.00037181024851076197
# Loss after 6350 iterations: 0.0003706259428108602
# Loss after 6400 iterations: 0.00036989174028833065
# Loss after 6450 iterations: 0.00036984983503213236
# Loss after 6500 iterations: 0.0003684650802662576

# %% [markdown]
# ### Visualize the results

# %%
plot(1:5000, losses[1:5000], yaxis=:log10, xlabel="Iterations", ylabel="Loss", label="ADAM", color=:blue)
plot!(5001:length(losses), losses[5001:end], yaxis=:log10, label="BFGS", color=:red)

# %%
X̂ = predict(p_trained, t)
plot(t, X̂', xlabel = "Time", ylabel = "Number of individuals", color = [:blue :red :green],
     label = ["UDE approximation" nothing nothing])
scatter!(t[begin:4:end], X_noisy', color = [:blue :red :green], label = ["Noisy data" nothing nothing])

# %%
plot(t, X', xlabel = "Time", ylabel = "Number of individuals", color = [:blue :red :green], 
     label = ["True trajectory" nothing nothing])
plot!(t, X̂', color = [:blue :red :green], linestyle = :dash, label = ["UDE approximation" nothing nothing])

# %%
# True residual dynamics (i.e. interactions of predictors) along the true trajectory
dynamics_true = [-β/N * (X[1, :] .* X[2, :])'; β/N * (X[1, :] .* X[2, :])'; zeros(length(t))']
# Neural network guess along the true trajectory
dynamics_nn = Lux.apply(model, X, p_trained, st)[1]

plot(t, dynamics_true', xlabel = "Time", ylabel = "Residual dynamics", 
     color = [:blue :red :green], label = ["True" nothing nothing])
plot!(t, dynamics_nn', color = [:blue :red :green], linestyle = :dash, label = ["NN(S,I,R)" nothing nothing])
